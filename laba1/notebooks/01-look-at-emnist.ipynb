# %% [markdown]
# # Looking at EMNIST data

# %%
import sys
sys.path
# Out:
# ['/usr/lib/python36.zip',
#  '/usr/lib/python3.6',
#  '/usr/lib/python3.6/lib-dynload',
#  '',
#  '/home/sidorkoda/workspace/full-stack-ml-course/.venv/lib/python3.6/site-packages',
#  '/home/sidorkoda/workspace/full-stack-ml-course/.venv/lib/python3.6/site-packages/IPython/extensions',
#  '/home/sidorkoda/.ipython',
#  '..']

# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from importlib.util import find_spec
if find_spec("datasets") is None:
    print('hello')
    import sys
    sys.path.append('..')

from datasets.emnist_dataset import EmnistDataset
# Out:
# hello

# %%
emnist_data = EmnistDataset()

# %%
emnist_data.load_or_generate_data()
emnist_data.x_train.shape, emnist_data.y_train.shape
# Out:
# ((336299, 28, 28), (336299, 80))

# %%
emnist_data.x_test.shape, emnist_data.y_test.shape
# Out:
# ((55789, 28, 28), (55789, 80))

# %%
fig = plt.figure(figsize=(9, 9))
for i in range(9):
    ax = fig.add_subplot(3, 3, i + 1)
    ax.imshow(emnist_data.x_train[i].reshape(28, 28), cmap='gray')
    ax.set_title(emnist_data.mapping[np.argmax(emnist_data.y_train[i])])
